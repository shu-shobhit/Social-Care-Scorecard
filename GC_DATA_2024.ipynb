# %%
import pandas as pd

import numpy as np

import plotly.express as px

import matplotlib.pyplot as plt

from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_excel('Social Determinants Raw Data 2020 by County - some parameters.xlsx', sheet_name = 'Data')

# %%
df.head()
# Out:
#    YEAR  COUNTYFIPS  STATEFIPS    STATE          COUNTY REGION  TERRITORY  \
# 0  2020        1001          1  Alabama  Autauga County  South          0
# 1  2020        1003          1  Alabama  Baldwin County  South          0
# 2  2020        1005          1  Alabama  Barbour County  South          0
# 3  2020        1007          1  Alabama     Bibb County  South          0
# 4  2020        1009          1  Alabama   Blount County  South          0
#
#    ACS_TOT_POP_WT  ACS_TOT_POP_US_ABOVE1  ACS_TOT_POP_ABOVE5  ...  \
# 0         55639.0                54929.0             52404.0  ...
# 1        218289.0               216518.0            206329.0  ...
# 2         25026.0                24792.0             23694.0  ...
# 3         22374.0                22073.0             21121.0  ...
# 4         57755.0                57164.0             54250.0  ...
#
#    POS_TOT_HOSP_AMBULANCE  POS_HOSP_AMBULANCE_RATE  POS_TOT_HOSP_CHEMO  \
# ...

# %%
# Out:
# YEAR                       0
# COUNTYFIPS                 0
# STATEFIPS                  0
# STATE                      0
# COUNTY                     0
#                           ..
# POS_HOSP_ED_RATE           2
# POS_PCT_HOSP_FOR_PROFIT    2
# POS_PCT_HOSP_NON_PROFIT    2
# POS_PCT_HOSP_GOV           2
# CEN_AIAN_NH_IND            1
# Length: 682, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Assuming df is your DataFrame containing the data
scaler = MinMaxScaler()
# Identify numeric columns
numeric_columns = df.select_dtypes(include=['int', 'float']).columns

# Extract numeric columns and normalize them
scaler = StandardScaler()
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# %%
df
# Out:
#       YEAR  COUNTYFIPS  STATEFIPS              STATE             COUNTY  \
# 0      0.0   -1.858382  -1.853811            Alabama     Autauga County
# 1      0.0   -1.858260  -1.853811            Alabama     Baldwin County
# 2      0.0   -1.858138  -1.853811            Alabama     Barbour County
# 3      0.0   -1.858016  -1.853811            Alabama        Bibb County
# 4      0.0   -1.857894  -1.853811            Alabama      Blount County
# ...    ...         ...        ...                ...                ...
# 3224   0.0    2.482419   2.481669        Puerto Rico  Yabucoa Municipio
# 3225   0.0    2.482541   2.481669        Puerto Rico    Yauco Municipio
# 3226   0.0    2.839871   2.848048  US Virgin Islands          St. Croix
# 3227   0.0    2.840482   2.848048  US Virgin Islands    St. John Island
# 3228   0.0    2.841092   2.848048  US Virgin Islands  St. Thomas Island
#
#      REGION  TERRITORY  ACS_TOT_POP_WT  ACS_TOT_POP_US_ABOVE1  \
# ...

# %%
numeric_df = df.select_dtypes(include=['int', 'float'])

# %%
corr = numeric_df.corr()

# %%
groups = []
for i in range(1,len(corr.columns)):
    for j in range(1,len(corr)):
        if(corr.iloc[i,j]>0.7):
            groups.append((corr.columns[i],corr.index[j]))

# %%
len(groups)
# Out:
# 10019

# %%
groups
# Out:
# [('COUNTYFIPS', 'COUNTYFIPS'),
#  ('COUNTYFIPS', 'STATEFIPS'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_1'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_2'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_3'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_4'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_5'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_6'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_7'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_8'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_9'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_10'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_11'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_12'),
#  ('COUNTYFIPS', 'CAF_ADJ_COUNTY_13'),
#  ('STATEFIPS', 'COUNTYFIPS'),
#  ('STATEFIPS', 'STATEFIPS'),
#  ('STATEFIPS', 'CAF_ADJ_COUNTY_1'),
#  ('STATEFIPS', 'CAF_ADJ_COUNTY_2'),
#  ('STATEFIPS', 'CAF_ADJ_COUNTY_3'),
#  ('STATEFIPS', 'CAF_ADJ_COUNTY_4'),
#  ('STATEFIPS', 'CAF_ADJ_COUNTY_5'),
#  ('STATEFIPS', 'CAF_ADJ_COUNTY_6'),
#  ('STATEFIPS', 'CAF_ADJ_COUNTY_7'),
#  ('STATEFIPS', 'CAF_ADJ_COUNTY_8'),
#  ('STATEFIPS', 'CAF_ADJ_COUNTY_9'),
# ...

# %%
from sklearn.cluster import KMeans

# %%
n_clusters = 5
random_state = 42
kmeans = KMeans(n_clusters=n_clusters, random_state=random_state)

# %%
numeric_df.isna().sum()
# Out:
# YEAR                       0
# COUNTYFIPS                 0
# STATEFIPS                  0
# TERRITORY                  0
# ACS_TOT_POP_WT             8
#                           ..
# POS_HOSP_ED_RATE           2
# POS_PCT_HOSP_FOR_PROFIT    2
# POS_PCT_HOSP_NON_PROFIT    2
# POS_PCT_HOSP_GOV           2
# CEN_AIAN_NH_IND            1
# Length: 679, dtype: int64

# %%
numeric_df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 numeric_df.isna().sum()
#
# NameError: name 'numeric_df' is not defined
